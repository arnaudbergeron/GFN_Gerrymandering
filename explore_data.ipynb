# %% [markdown]
# # Pennsylvania

# %% [markdown]
# ## Full raw data

# %%
import pandas as pd
import json

# Load the JSON file
with open('data/PA_raw_data.json', 'r') as file:
    data = json.load(file)

# Flatten the JSON structure into a DataFrame
df = pd.json_normalize(data)

# %%
df.head(10)
# Out:
#          GEOID state        county   muni        county_muni  cd_2010  \
# 0  42001000010    PA  Adams County  00116  Adams County00116       13
# 1  42001000020    PA  Adams County  02928  Adams County02928       13
# 2  42001000030    PA  Adams County  46376  Adams County05536       13
# 3  42001000040    PA  Adams County    NaN       Adams County       13
# 4  42001000050    PA  Adams County  07560  Adams County06296       13
# 5  42001000060    PA  Adams County    NaN  Adams County07560       13
# 6  42001000070    PA  Adams County    NaN       Adams County       13
# 7  42001000078    PA  Adams County  11472  Adams County11472       13
# 8  42001000082    PA  Adams County    NaN  Adams County11472       13
# 9  42001000090    PA  Adams County    NaN       Adams County       13
#
#    cd_2020     vtd   pop  pop_hisp  ...  arv_20  adv_20    nrv    ndv  \
# 0       13  000010  1022       132  ...   350.5   139.5  272.6  132.3
# ...

# %%
df.shape
# Out:
# (9178, 54)

# %%
df['adj'].head(10)
# Out:
# 0                                  [3, 24, 9090]
# 1                                        [6, 18]
# 2                                           [34]
# 3           [0, 9, 24, 40, 41, 9055, 9090, 9095]
# 4                                            [6]
# 5                                           [37]
# 6                     [1, 4, 11, 18, 34, 46, 47]
# 7                                    [8, 25, 29]
# 8                                    [7, 25, 29]
# 9    [3, 10, 32, 33, 40, 9052, 9053, 9092, 9095]
# Name: adj, dtype: object

# %% [markdown]
# ## Raw plans

# %%
import pandas as pd
import json

# Load the JSON file
with open('data/PA_raw_plans.json', 'r') as file:
    data = json.load(file)

# Flatten the JSON structure into a DataFrame
df_plans = pd.json_normalize(data)

# %%
df_plans.head(20)
# Out:
#        draw  district  total_pop  chain
# 0   cd_2020         1     765457    NaN
# 1   cd_2020         2     764865    NaN
# 2   cd_2020         3     764864    NaN
# 3   cd_2020         4     766240    NaN
# 4   cd_2020         5     765179    NaN
# 5   cd_2020         6     763498    NaN
# 6   cd_2020         7     767801    NaN
# 7   cd_2020         8     761414    NaN
# 8   cd_2020         9     762523    NaN
# 9   cd_2020        10     765120    NaN
# 10  cd_2020        11     763503    NaN
# 11  cd_2020        12     764826    NaN
# 12  cd_2020        13     765972    NaN
# 13  cd_2020        14     764683    NaN
# 14  cd_2020        15     766538    NaN
# 15  cd_2020        16     765018    NaN
# 16  cd_2020        17     765199    NaN
# 17        1         1     763723    1.0
# 18        1         2     767048    1.0
# 19        1         3     763600    1.0

# %%
df_plans.shape
# Out:
# (85017, 4)
